# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguage Natural
#
# ## Taller #9: Nube de Palabrass
# ### Estudiante: Ilvar Dario Sanabria.
# ### Código: 616201058
# `Fecha de entrega: Noviembre 7, 2020. (Antes del inicio de la próxima clase).`
#
# `Modo de entrega: Subir link de GitHub al aula virtual.`

# %%
import numpy as np
import pandas as pd 
 
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
 
from nltk.corpus import stopwords

stopwords = stopwords.words('spanish')
 
import matplotlib.pyplot as plt
import PIL.Image

from IPython.display import display

# %% [markdown]
# #### Utilizo la BD que tengo de textos de la HC de pacientes que van a un servicio médico

# %%
data = pd.read_excel('c:/tmp/REPORTE_IVE.xlsx')
data.head()
# Out:
#                                    ENFERMEDAD_ACTUAL  \
# 0  se presenta a consulta  femenina de 18 años. s...
# 1  PACIENTE DE 28 AÑOS QUIEN ASISTE SOLICITANDO I...
# 2  PACIENTE DE 24 AÑOS QUIEN ASISTE VOLUNTARIAMEN...
# 3  Refiere embarazo no planeado y manifiesta impo...
# 4  PACIENTE DE 22 AÑOS QUIEN ASISTE VOLUNTARIAMEN...
#
#                                      MOTIVO_CONSULTA TIENE_VIOLENCIA  \
# 0                             " volvi a la consulta"               N
# 1                  "QUIERO INTERRUMPIR EL EMBARAZO"                S
# 2                   "QUIERO INTERRUMPIR EL EMBARAZO"               N
# 3  Valoración médica para Interrupción Voluntaria...               N
# 4                   "QUIERO INTERRUMPIR EL EMBARAZO"               N
#
#                                          PLAN_MANEJO  \
# 0  se certifica ive por causal salud. procedimien...
# 1  PACIENTE EN LA SEGUNDA DECADA DE LA VIDA CON E...
# 2  PACIENTE EN LA SEGUNDA DECADA DE LA VIDA CON E...
# ...

# %%
palabras=data.ENFERMEDAD_ACTUAL.str.cat(sep=' ')

# %%
#Generamos la nube de palabras
wordcloud = WordCloud().generate(palabras)

#Graficamos la nube de palabras
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# ### Mejoramos la grafica

# %%
# Más en https://www.datacamp.com/community/tutorials/wordcloud-python

palabras = data.ENFERMEDAD_ACTUAL.str.cat(sep=' ')
 
wordcloud = WordCloud(width=800, height=400,                
                      max_font_size=150, max_words=250,
                      background_color='white', colormap='gist_heat',
                      stopwords=stopwords).generate(palabras) # https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html
 
plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()

# %% [markdown]
# ## Cargar una imagen.
# ### Para este caso seleccione una imagen de mafalda en blanco y engro, a al cual se le retocó el fondo porque no estaba completamente transparente y algunos bordes para que quedaran más definidos

# %%
Mujer = PIL.Image.open("c:/tmp/Mafalda.jpg")

display(Mujer)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x841 at 0x199179C7248>

# %%
#Se crear una mascara

# %%
SimboloMujer = np.array(Mujer)
SimboloMujer
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %% [markdown]
# ##  Aplicamos la mascara con la grafica anterior
# ### Jugue con las paletas de colores y con los colores de la imagen original, pero creo que la mejor figura es dejarla transparente y aplicar la paleta gist_heat

# %%
# Más en https://www.datacamp.com/community/tutorials/wordcloud-python

palabras = data.ENFERMEDAD_ACTUAL.str.cat(sep=' ')
 
wordcloud = WordCloud(width=800, height=400,
                      max_font_size=150, max_words=250,
                      background_color='white', colormap='gist_heat',
                      stopwords=stopwords,
                      mask=SimboloMujer, contour_width=2, contour_color='black').generate(palabras) # https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html
 
wordcloud.to_file("PalabrasMujer.png")

#image_colors = ImageColorGenerator(SimboloMujer)
#wordcloud.recolor(color_func=image_colors)

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()
